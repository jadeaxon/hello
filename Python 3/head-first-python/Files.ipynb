# %%
import swimclub

swimclub.main()
# Out:
# c:\Users\jadea\projects\hello\Python 3\head-first-python
# ('Abi', 10, '100m', 'back', ['1:31.59', '1:26.55', '1:28.75', '1:39.79', '1:32.37'], '1:31.81')
# ('Abi', 10, '100m', 'breast', ['1:42.97', '1:43.31', '1:43.50', '1:40.34'], '1:42.53')
# ('Abi', 10, '50m', 'back', ['41.50', '43.58', '42.35', '43.35', '39.85', '40.53', '42.14', '39.18', '40.89', '40.89'], '41.43')
# ('Abi', 10, '50m', 'breast', ['48.08', '53.17', '45.76', '49.28', '52.85', '46.19', '47.76', '48.83', '45.71', '47.76'], '48.54')
# ('Abi', 10, '50m', 'free', ['39.07', '37.66', '36.13', '39.42'], '38.7')
# ('Ali', 12, '100m', 'back', ['1:36.54', '1:39.10', '1:39.45', '1:42.87'], '1:39.49')
# ('Ali', 12, '100m', 'free', ['1:27.31', '1:27.00', '1:27.46', '1:22.50', '1:20.39', '1:26.04', '1:20.22'], '1:24.42')
# ('Alison', 14, '100m', 'breast', ['1:34.71', '1:37.87', '1:35.15', '1:37.20', '1:36.29', '1:36.00', '1:35.63', '1:35.42', '1:42.01'], '1:36.70')
# ...
