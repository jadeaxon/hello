# %%
import random

suits = ["Clubs", "Spades", "Hearts", "Diamonds"]
faces = ["Jack", "Queen", "King", "Ace"]
numbered = [2, 3, 4, 5, 6, 7, 8, 9, 10]

print(suits)

deck = set()
for s in suits:
    for v in faces + numbered:
        deck.add((v, "of", s))
print(len(deck))
# Out:
# ['Clubs', 'Spades', 'Hearts', 'Diamonds']
# 52

# %%
suits

def draw():
    """
    while True:
        the_suit = random.choice(suits)
        the_card = random.choice(faces + numbered)
        card = (the_card, "of", the_suit)
        if card in deck: break
    """
    card = random.choice(list(deck))
    deck.remove(card)
    return card

draw()
# Out:
# ('Jack', 'of', 'Clubs')

# %%
for _ in range(5):
    print(draw())
# Out:
# (6, 'of', 'Clubs')
# ('Queen', 'of', 'Clubs')
# (7, 'of', 'Diamonds')
# (2, 'of', 'Diamonds')
# ('Queen', 'of', 'Spades')

# %%
card = ("Ace", "of", "Hearts")
card in deck
# Out:
# True
