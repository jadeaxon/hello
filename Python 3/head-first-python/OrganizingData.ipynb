# %%
import os

import swimclub


swim_files = os.listdir(swimclub.SWIM_DATA_DIR)


print(len(swim_files))
# Out:
# 60

# %%
swimmers = []
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    swimmers.append(swimclub.read_swim_data(file)[0])
print(swimmers)
# Out:
# ['Abi', 'Abi', 'Abi', 'Abi', 'Abi', 'Ali', 'Ali', 'Alison', 'Alison', 'Aurora', 'Bill', 'Bill', 'Blake', 'Blake', 'Blake', 'Calvin', 'Calvin', 'Calvin', 'Carl', 'Chris', 'Chris', 'Darius', 'Darius', 'Darius', 'Darius', 'Dave', 'Dave', 'Elba', 'Emma', 'Emma', 'Erika', 'Erika', 'Erika', 'Hannah', 'Hannah', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Lizzie', 'Lizzie', 'Maria', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike', 'Owen', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Tasmin', 'Tasmin', 'Tasmin', 'Tasmin']

# %%
names = list(set(swimmers))

# %%
print(names)
# Out:
# ['Blake', 'Darius', 'Ali', 'Chris', 'Emma', 'Abi', 'Aurora', 'Bill', 'Elba', 'Alison', 'Erika', 'Tasmin', 'Dave', 'Ruth', 'Lizzie', 'Carl', 'Calvin', 'Hannah', 'Katie', 'Owen', 'Mike', 'Maria']

# %%
len(names)
# Out:
# 22

# %%
swimmers = []
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    name = swimclub.read_swim_data(file)[0]
    if name not in swimmers:
        swimmers.append(name)
print(swimmers)
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
print(sorted(names))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
print(sorted(swimmers))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
swimmers = []
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    swimmers.append(swimclub.read_swim_data(file)[0])
print(swimmers)
# Out:
# ['Abi', 'Abi', 'Abi', 'Abi', 'Abi', 'Ali', 'Ali', 'Alison', 'Alison', 'Aurora', 'Bill', 'Bill', 'Blake', 'Blake', 'Blake', 'Calvin', 'Calvin', 'Calvin', 'Carl', 'Chris', 'Chris', 'Darius', 'Darius', 'Darius', 'Darius', 'Dave', 'Dave', 'Elba', 'Emma', 'Emma', 'Erika', 'Erika', 'Erika', 'Hannah', 'Hannah', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Lizzie', 'Lizzie', 'Maria', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike', 'Owen', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Tasmin', 'Tasmin', 'Tasmin', 'Tasmin']

# %%
swimmers = []
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    swimclub.read_swim_data(file)[0]
    swimmers.append((swimclub.read_swim_data(file)[0], file))

# %%
len(swimmers)
# Out:
# 60

# %%
swimmers[:5]
# Out:
# [('Abi', 'data/Abi-10-100m-Back.txt'),
#  ('Abi', 'data/Abi-10-100m-Breast.txt'),
#  ('Abi', 'data/Abi-10-50m-Back.txt'),
#  ('Abi', 'data/Abi-10-50m-Breast.txt'),
#  ('Abi', 'data/Abi-10-50m-Free.txt')]

# %%
names = []
for row in swimmers:
    if row[0] not in names:
        names.append(row[0])
print(sorted(names))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
for event in swimmers:
    if event[0] == "Dave":
        print(event)
# Out:
# ('Dave', 'data/Dave-17-100m-Free.txt')
# ('Dave', 'data/Dave-17-200m-Back.txt')

# %%
for n, event in enumerate(swimmers):
    if event[0] == "Dave":
        print(n, event)
# Out:
# 25 ('Dave', 'data/Dave-17-100m-Free.txt')
# 26 ('Dave', 'data/Dave-17-200m-Back.txt')

# %%
person = {
    "first": "Tim",
    "last": "O'Reilly",
}

# %%
person["first"]
# Out:
# 'Tim'

# %%
person["last"]
# Out:
# "O'Reilly"

# %%
names = {}

# %%
names["Dave"] = "Dave-17-100m-Free.txt"

# %%
swimmers = {}
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    name, *_ = swimclub.read_swim_data(file)
    swimmers[name] = []

# %%
swimmers
# Out:
# {'Abi': [],
#  'Ali': [],
#  'Alison': [],
#  'Aurora': [],
#  'Bill': [],
#  'Blake': [],
#  'Calvin': [],
#  'Carl': [],
#  'Chris': [],
#  'Darius': [],
#  'Dave': [],
#  'Elba': [],
#  'Emma': [],
#  'Erika': [],
#  'Hannah': [],
#  'Katie': [],
#  'Lizzie': [],
#  'Maria': [],
#  'Mike': [],
#  'Owen': [],
#  'Ruth': [],
#  'Tasmin': []}

# %%
len(swimmers)
# Out:
# 22

# %%
print(sorted(swimmers))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
swimmers["Dave"]
# Out:
# []

# %%
print(dir(swimmers))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
swimmers = {}
for file in swim_files:
    file = f"{swimclub.SWIM_DATA_DIR}/{file}"
    name, *_ = swimclub.read_swim_data(file)
    if name not in swimmers:
        swimmers[name] = []
    swimmers[name].append(file)

# %%
swimmers["Dave"]
# Out:
# ['data/Dave-17-100m-Free.txt', 'data/Dave-17-200m-Back.txt']

# %%
swimmers["Darius"]
# Out:
# ['data/Darius-13-100m-Back.txt',
#  'data/Darius-13-100m-Breast.txt',
#  'data/Darius-13-100m-Fly.txt',
#  'data/Darius-13-200m-IM.txt']

# %%
swimmers["Emma"]
# Out:
# ['data/Emma-13-100m-Breast.txt', 'data/Emma-13-100m-Free.txt']

# %%
swimmers["Calvin"]
# Out:
# ['data/Calvin-9-50m-Back.txt',
#  'data/Calvin-9-50m-Fly.txt',
#  'data/Calvin-9-50m-Free.txt']

# %%
swimmers["Katie"]
# Out:
# ['data/Katie-9-100m-Back.txt',
#  'data/Katie-9-100m-Breast.txt',
#  'data/Katie-9-100m-Free.txt',
#  'data/Katie-9-50m-Back.txt',
#  'data/Katie-9-50m-Breast.txt',
#  'data/Katie-9-50m-Fly.txt',
#  'data/Katie-9-50m-Free.txt']

# %%
swimmers
# Out:
# {'Abi': ['data/Abi-10-100m-Back.txt',
#   'data/Abi-10-100m-Breast.txt',
#   'data/Abi-10-50m-Back.txt',
#   'data/Abi-10-50m-Breast.txt',
#   'data/Abi-10-50m-Free.txt'],
#  'Ali': ['data/Ali-12-100m-Back.txt', 'data/Ali-12-100m-Free.txt'],
#  'Alison': ['data/Alison-14-100m-Breast.txt', 'data/Alison-14-100m-Free.txt'],
#  'Aurora': ['data/Aurora-13-50m-Free.txt'],
#  'Bill': ['data/Bill-18-100m-Back.txt', 'data/Bill-18-200m-Back.txt'],
#  'Blake': ['data/Blake-15-100m-Back.txt',
#   'data/Blake-15-100m-Fly.txt',
#   'data/Blake-15-100m-Free.txt'],
#  'Calvin': ['data/Calvin-9-50m-Back.txt',
#   'data/Calvin-9-50m-Fly.txt',
#   'data/Calvin-9-50m-Free.txt'],
#  'Carl': ['data/Carl-15-100m-Back.txt'],
#  'Chris': ['data/Chris-17-100m-Back.txt', 'data/Chris-17-100m-Breast.txt'],
#  'Darius': ['data/Darius-13-100m-Back.txt',
#   'data/Darius-13-100m-Breast.txt',
#   'data/Darius-13-100m-Fly.txt',
#   'data/Darius-13-200m-IM.txt'],
#  'Dave': ['data/Dave-17-100m-Free.txt', 'data/Dave-17-200m-Back.txt'],
#  'Elba': ['data/Elba-14-100m-Free.txt'],
#  'Emma': ['data/Emma-13-100m-Breast.txt', 'data/Emma-13-100m-Free.txt'],
#  'Erika': ['data/Erika-15-100m-Breast.txt',
#   'data/Erika-15-100m-Free.txt',
#   'data/Erika-15-200m-Breast.txt'],
#  'Hannah': ['data/Hannah-13-100m-Back.txt', 'data/Hannah-13-100m-Free.txt'],
#  'Katie': ['data/Katie-9-100m-Back.txt',
#   'data/Katie-9-100m-Breast.txt',
#   'data/Katie-9-100m-Free.txt',
#   'data/Katie-9-50m-Back.txt',
#   'data/Katie-9-50m-Breast.txt',
#   'data/Katie-9-50m-Fly.txt',
#   'data/Katie-9-50m-Free.txt'],
#  'Lizzie': ['data/Lizzie-14-100m-Back.txt', 'data/Lizzie-14-100m-Free.txt'],
#  'Maria': ['data/Maria-9-50m-Free.txt'],
#  'Mike': ['data/Mike-15-100m-Back.txt',
#   'data/Mike-15-100m-Fly.txt',
#   'data/Mike-15-100m-Free.txt',
#   'data/Mike-15-200m-Free.txt',
#   'data/Mike-15-200m-IM.txt'],
#  'Owen': ['data/Owen-15-100m-Free.txt'],
#  'Ruth': ['data/Ruth-13-100m-Back.txt',
#   'data/Ruth-13-100m-Free.txt',
#   'data/Ruth-13-200m-Back.txt',
#   'data/Ruth-13-200m-Free.txt',
#   'data/Ruth-13-400m-Free.txt'],
#  'Tasmin': ['data/Tasmin-15-100m-Back.txt',
#   'data/Tasmin-15-100m-Breast.txt',
#   'data/Tasmin-15-100m-Free.txt',
#   'data/Tasmin-15-200m-Breast.txt']}

# %%
import pprint

pprint.pprint(swimmers)
# Out:
# {'Abi': ['data/Abi-10-100m-Back.txt',
#          'data/Abi-10-100m-Breast.txt',
#          'data/Abi-10-50m-Back.txt',
#          'data/Abi-10-50m-Breast.txt',
#          'data/Abi-10-50m-Free.txt'],
#  'Ali': ['data/Ali-12-100m-Back.txt', 'data/Ali-12-100m-Free.txt'],
#  'Alison': ['data/Alison-14-100m-Breast.txt', 'data/Alison-14-100m-Free.txt'],
#  'Aurora': ['data/Aurora-13-50m-Free.txt'],
#  'Bill': ['data/Bill-18-100m-Back.txt', 'data/Bill-18-200m-Back.txt'],
#  'Blake': ['data/Blake-15-100m-Back.txt',
#            'data/Blake-15-100m-Fly.txt',
#            'data/Blake-15-100m-Free.txt'],
#  'Calvin': ['data/Calvin-9-50m-Back.txt',
#             'data/Calvin-9-50m-Fly.txt',
#             'data/Calvin-9-50m-Free.txt'],
#  'Carl': ['data/Carl-15-100m-Back.txt'],
#  'Chris': ['data/Chris-17-100m-Back.txt', 'data/Chris-17-100m-Breast.txt'],
#  'Darius': ['data/Darius-13-100m-Back.txt',
#             'data/Darius-13-100m-Breast.txt',
#             'data/Darius-13-100m-Fly.txt',
#             'data/Darius-13-200m-IM.txt'],
#  'Dave': ['data/Dave-17-100m-Free.txt', 'data/Dave-17-200m-Back.txt'],
#  'Elba': ['data/Elba-14-100m-Free.txt'],
#  'Emma': ['data/Emma-13-100m-Breast.txt', 'data/Emma-13-100m-Free.txt'],
#  'Erika': ['data/Erika-15-100m-Breast.txt',
#            'data/Erika-15-100m-Free.txt',
#            'data/Erika-15-200m-Breast.txt'],
#  'Hannah': ['data/Hannah-13-100m-Back.txt', 'data/Hannah-13-100m-Free.txt'],
#  'Katie': ['data/Katie-9-100m-Back.txt',
#            'data/Katie-9-100m-Breast.txt',
#            'data/Katie-9-100m-Free.txt',
#            'data/Katie-9-50m-Back.txt',
#            'data/Katie-9-50m-Breast.txt',
#            'data/Katie-9-50m-Fly.txt',
#            'data/Katie-9-50m-Free.txt'],
#  'Lizzie': ['data/Lizzie-14-100m-Back.txt', 'data/Lizzie-14-100m-Free.txt'],
#  'Maria': ['data/Maria-9-50m-Free.txt'],
#  'Mike': ['data/Mike-15-100m-Back.txt',
#           'data/Mike-15-100m-Fly.txt',
#           'data/Mike-15-100m-Free.txt',
#           'data/Mike-15-200m-Free.txt',
#           'data/Mike-15-200m-IM.txt'],
#  'Owen': ['data/Owen-15-100m-Free.txt'],
#  'Ruth': ['data/Ruth-13-100m-Back.txt',
#           'data/Ruth-13-100m-Free.txt',
#           'data/Ruth-13-200m-Back.txt',
#           'data/Ruth-13-200m-Free.txt',
#           'data/Ruth-13-400m-Free.txt'],
#  'Tasmin': ['data/Tasmin-15-100m-Back.txt',
#             'data/Tasmin-15-100m-Breast.txt',
#             'data/Tasmin-15-100m-Free.txt',
#             'data/Tasmin-15-200m-Breast.txt']}

# %%
import os
import webbrowser

import swimclub


for fname in swimmers["Calvin"]:
    webbrowser.open("file://" + os.path.realpath(swimclub.produce_bar_chart(fname)))
# Out:
# Calvin (age 9) 50m back
# Calvin (age 9) 50m fly
# Calvin (age 9) 50m free
